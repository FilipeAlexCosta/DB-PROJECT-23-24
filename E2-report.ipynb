# %% [markdown]
# # Projeto de Bases de Dados - Parte 2
#
# ### Docente Responsável
#
# Prof. Franscisco Regateiro
#
# ### Grupo 47
# <dl>
#     <dt>4 horas (33.3%)</dt>
#     <dd>ist1103561 Tiago Cardoso</dd>
#     <dt>4 horas (33.3%)</dt>
#     <dd>ist1106266 Filipe Costa</dd>
#     <dt>4 horas (33.3%)</dt>
#     <dd>ist1106583 Francisco Mónica</dd>
# <dl>

# %%
# %load_ext sql
# %config SqlMagic.displaycon = 0
# %config SqlMagic.displaylimit = 100
# %sql postgresql+psycopg://saude:saude@postgres/saude
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting and switching to connection 'postgresql+psycopg://saude:***@postgres/saude'

# %% [markdown]
# ## 0. Carregamento da Base de Dados
#
# Crie a base de dados “Saude” no PostgreSQL e execute os comandos para criação das tabelas desta base de dados apresentados de seguida

# %%
# %%sql
#
# DROP TABLE IF EXISTS clinica CASCADE;
# DROP TABLE IF EXISTS enfermeiro CASCADE;
# DROP TABLE IF EXISTS medico CASCADE;
# DROP TABLE IF EXISTS trabalha CASCADE;
# DROP TABLE IF EXISTS paciente CASCADE;
# DROP TABLE IF EXISTS receita CASCADE;
# DROP TABLE IF EXISTS consulta CASCADE;
# DROP TABLE IF EXISTS observacao CASCADE;
#
# CREATE TABLE clinica(
# 	nome VARCHAR(80) PRIMARY KEY,
# 	telefone VARCHAR(15) UNIQUE NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) UNIQUE NOT NULL
# );
#
# CREATE TABLE enfermeiro(
# 	nif CHAR(9) PRIMARY KEY CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) UNIQUE NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	nome_clinica VARCHAR(80) NOT NULL REFERENCES clinica (nome)
# );
#
# CREATE TABLE medico(
# 	nif CHAR(9) PRIMARY KEY CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) UNIQUE NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	especialidade VARCHAR(80) NOT NULL
# );
#
# CREATE TABLE trabalha(
# nif CHAR(9) NOT NULL REFERENCES medico,
# nome VARCHAR(80) NOT NULL REFERENCES clinica,
# dia_da_semana SMALLINT,
# PRIMARY KEY (nif, dia_da_semana)
# );
#
# CREATE TABLE paciente(
# 	ssn CHAR(11) PRIMARY KEY CHECK (ssn ~ '^[0-9]+$'),
# nif CHAR(9) UNIQUE NOT NULL CHECK (nif ~ '^[0-9]+$'),
# 	nome VARCHAR(80) NOT NULL,
# 	telefone VARCHAR(15) NOT NULL CHECK (telefone ~ '^[0-9]+$'),
# 	morada VARCHAR(255) NOT NULL,
# 	data_nasc DATE NOT NULL
# );
#
# CREATE TABLE consulta(
# 	id SERIAL PRIMARY KEY,
# 	ssn CHAR(11) NOT NULL REFERENCES paciente,
# 	nif CHAR(9) NOT NULL REFERENCES medico,
# 	nome VARCHAR(80) NOT NULL REFERENCES clinica,
# 	data DATE NOT NULL,
# 	hora TIME NOT NULL,
# 	codigo_sns CHAR(12) UNIQUE CHECK (codigo_sns ~ '^[0-9]+$'),
# 	UNIQUE(ssn, data, hora),
# 	UNIQUE(nif, data, hora)
# );
#
# CREATE TABLE receita(
# 	codigo_sns VARCHAR(12) NOT NULL REFERENCES consulta (codigo_sns),
# 	medicamento VARCHAR(155) NOT NULL,
# 	quantidade SMALLINT NOT NULL CHECK (quantidade > 0),
# 	PRIMARY KEY (codigo_sns, medicamento)
# );
#
# CREATE TABLE observacao(
# 	id INTEGER NOT NULL REFERENCES consulta,
# 	parametro VARCHAR(155) NOT NULL,
# 	valor FLOAT,
# PRIMARY KEY (id, parametro)
# );
#
# -- Criação da tabela auxiliar utilizada para selecionar os horários disponíveis dos médicos no ponto 3
# -- Cria todos os horários possíveis em 2024 (para cada dia, das 08:00:00 até às 13:00:00 e das 14:00:00
# -- até às 19:00:00 em intervalos de meia hora, como especificado no enunciado)
# CREATE TABLE datas AS (
#     SELECT
#         serie::date AS data, serie::time as hora
#     FROM
#         generate_series(timestamp '2024-01-01', timestamp '2024-12-31', interval '30 min') AS serie
#     WHERE
#         ((serie::time BETWEEN '08:00:00' AND '12:30:00') OR
#         (serie::time BETWEEN '14:00:00' AND '18:30:00')) AND
#         serie::timestamp > NOW()::timestamp
# );

# %% [markdown]
# ## 1. Restrições de Integridade
#
# Apresente o código para implementar as seguintes restrições de integridade, se necessário, com recurso a extensões procedimentais SQL (Stored Procedures e Triggers):

# %% [markdown]
# (RI-1) Os horários das consultas são à hora exata ou meia-hora no horário 8-13h e 14-19h

# %%
# %%sql
# -- (RI-1)
# ALTER TABLE consulta ADD CONSTRAINT verifica_hora
# 	CHECK(EXTRACT(SECOND FROM hora) = 0	AND
# 		(EXTRACT(MINUTE FROM hora) = 0 OR EXTRACT(MINUTE FROM hora) = 30) AND
# 		(hora BETWEEN '08:00:00' AND '12:30:00' OR hora BETWEEN '14:00:00' AND '18:30:00'));

# %% [markdown]
# (RI-2) Um médico não se pode consultar a si próprio, embora possa ser paciente de outros médicos no sistema

# %%
# %%sql
# -- (RI-2)
# CREATE OR REPLACE FUNCTION verifica_auto_consulta() RETURNS TRIGGER AS
# $$
# BEGIN
# 	IF NEW.nif = (SELECT nif FROM paciente WHERE ssn = NEW.ssn) THEN
# 		RAISE EXCEPTION 'O médico % não pode consultar-se a si próprio.', NEW.nif;
# 	END IF;
# 	RETURN NEW;
# END;
# $$
# LANGUAGE plpgsql;
#
# DROP TRIGGER IF EXISTS proibe_auto_consulta ON consulta;
# CREATE CONSTRAINT TRIGGER proibe_auto_consulta
#     AFTER INSERT OR UPDATE ON consulta
#     FOR EACH ROW EXECUTE FUNCTION verifica_auto_consulta();

# %% [markdown]
# (RI-3) Um médico só pode dar consultas na clínica em que trabalha no dia da semana correspondente à data da consulta

# %%
# %%sql
# -- (RI-3)
# CREATE OR REPLACE FUNCTION verifica_local_trabalho() RETURNS TRIGGER AS
# $$
# BEGIN
# 	IF NEW.nome != (SELECT nome FROM trabalha WHERE nif = NEW.nif
# 		AND dia_da_semana = EXTRACT(DOW FROM NEW.data)) THEN
# 		RAISE EXCEPTION 'O médico % não trabalha na clínica % no dia %',
# 			NEW.nif, NEW.nome, NEW.data;
# 	END IF;
# 	RETURN NEW;
# END;
# $$
# LANGUAGE plpgsql;
#
# DROP TRIGGER IF EXISTS proibe_consultas_fora_clinica ON consulta;
# CREATE CONSTRAINT TRIGGER proibe_consultas_fora_clinica
# 	AFTER INSERT OR UPDATE ON consulta
# 	FOR EACH ROW EXECUTE FUNCTION verifica_local_trabalho();

# %% [markdown]
# ## 2. Preenchimento da Base de Dados
#
# Preencha todas as tabelas da base de dados de forma consistente (após execução do ponto anterior) com os seguintes requisitos adicionais de cobertura:
# - 5 clínicas, de pelo menos 3 localidades diferentes do distrito de Lisboa
# - 5-6 enfermeiros por clínica
# - 20 médicos de especialidade ‘clínica geral’ e 40 outros distribuídos como entender por até 5 outras especialidades médicas (incluindo pelo menos, ‘ortopedia’ e ‘cardiologia’). Cada médico deve trabalhar em pelo menos duas clínicas, e em cada clínica a cada dia da semana (incluindo fins de semana), devem estar pelo menos 8 médicos
# - Cerca de 5.000 pacientes
# - Um número mínimo de consultas em 2023 e 2024 tais que cada paciente tem pelo menos uma consulta, e em cada dia há pelo menos 20 consultas por clínica, e pelo menos 2 consultas por médico
# - ~80% das consultas tem receita médica associada, e as receitas têm 1 a 6 medicamentos em quantidades entre 1 e 3
# - Todas as consultas têm 1 a 5 observações de sintomas (com parâmetro mas sem valor) e 0 a 3 observações métricas (com parâmetro e valor). Deve haver ~50 parâmetros diferentes para os sintomas (sem valor) e ~20 parâmetros diferentes para as observações métricas (com valor) e os dois conjuntos devem ser disjuntos.
# - Todas as moradas são nacionais e seguem o formato Português, terminando com código postal: XXXX-XXX e de seguida a localidade.
# Deve ainda garantir que todas as consultas necessárias para a realização dos pontos seguintes do projeto produzem um resultado não vazio.
#
# O código para preenchimento da base de dados deve ser compilado num ficheiro "populate.sql", anexado ao relatório, que contém com comandos INSERT ou alternativamente comandos COPY que populam as tabelas a partir de ficheiros de texto, também eles anexados ao relatório.

# %% [markdown]
# ## 3. Desenvolvimento de Aplicação
#
# Crie um protótipo de RESTful web service para gestão de consultas por acesso programático à base de dados ‘Saude’ através de uma API que devolve respostas em JSON, implementando os seguintes endpoints REST:
#
# |Endpoint|Descrição|
# |--------|---------|
# |/|Lista todas as clínicas (nome e morada).|
# |/c/\<clinica>/|Lista todas as especialidades oferecidas na \<clinica>.|
# |/c/\<clinica>/\<especialidade>/|Lista todos os médicos (nome) da \<especialidade> que trabalham na <clínica> e os primeiros três horários disponíveis para consulta de cada um deles (data e hora).|
# |/a/\<clinica>/registar/|Registra uma marcação de consulta na \<clinica> na base de dados (populando a respectiva tabela). Recebe como argumentos um paciente, um médico, e uma data e hora (posteriores ao momento de agendamento).|
# |/a/\<clinica>/cancelar/|Cancela uma marcação de consulta que ainda não se realizou na \<clinica> (o seu horário é posterior ao momento do cancelamento), removendo a entrada da respectiva tabela na base de dados. Recebe como argumentos um paciente, um médico, e uma data e hora.|

# %% [markdown]
# ### Explicação da arquitetura da aplicação web, incluindo a descrição dos vários ficheiros na pasta web/arquivos e a relação entre eles
#
# ...

# %% [markdown]
# ## 3. Vistas
#
# Crie uma vista materializada que detalhe as informações mais importantes sobre as consultas dos pacientes, combinando a informação de várias tabelas da base de dados. A vista deve ter o seguinte esquema:
#
# ### *historial_paciente(id, ssn, nif, nome, data, ano, mes, dia_do_mes, localidade, especialidade, tipo, chave, valor)*
#
# em que:
# - *id, ssn, nif, nome* e *data*: correspondem ao atributos homónimos da tabela **consulta**
# - *ano*, *mes* e *dia_do_mes*: são derivados do atributo *data* da tabela **consulta**
# - *localidade*: é derivado do atributo *morada* da tabela **clinica**
# - *especialidade*: corresponde ao atributo homónimo da tabela **medico**
# - *tipo*: toma os valores ‘observacao’ ou ‘receita’ consoante o preenchimento dos campos seguintes
# - *chave*: corresponde ao atributo *parametro* da tabela **observacao** ou ao atributo *medicamento* da tabela **receita**
# - *valor*: corresponde ao atributo *valor* da tabela **observacao** ou ao atributo *quantidade* da tabela **receita**

# %%
# %%sql
# CREATE MATERIALIZED VIEW IF NOT EXISTS historial_paciente AS
#     SELECT
#         con.id AS id, con.ssn AS ssn, con.nif AS nif, con.nome AS nome, con.data AS data,
#         EXTRACT(YEAR FROM con.data) AS ano, EXTRACT(MONTH FROM con.data) AS mes, EXTRACT(DAY FROM con.data) AS dia_do_mes,
#         cli.morada AS localidade,
#         med.especialidade AS especialidade,
#         'observacao' AS tipo,
#         obs.parametro AS chave,
#         obs.valor AS valor
#     FROM
#         consulta con INNER JOIN clinica cli ON con.nome = cli.nome
#         INNER JOIN medico med ON con.nif = med.nif
#         INNER JOIN observacao obs ON con.id = obs.id
#     UNION
#     SELECT
#         con.id AS id, con.ssn AS ssn, con.nif AS nif, con.nome AS nome, con.data AS data,
#         EXTRACT(YEAR FROM con.data) AS ano, EXTRACT(MONTH FROM con.data) AS mes, EXTRACT(DAY FROM con.data) AS dia_do_mes,
#         cli.morada AS localidade,
#         med.especialidade AS especialidade,
#         'receita' AS tipo,
#         rec.medicamento AS chave,
#         rec.quantidade AS valor
#     FROM
#         consulta con INNER JOIN clinica cli ON con.nome = cli.nome
#         INNER JOIN medico med ON con.nif = med.nif
#         INNER JOIN receita rec ON con.codigo_sns = rec.codigo_sns;
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ## 5. Análise de Dados (SQL e OLAP
#
# Usando a vista desenvolvida no ponto anterior, complementada com outras tabelas da base de dados ‘Saude’ quando necessário, apresente a consulta SQL mais sucinta para cada um dos seguintes objetivos analíticos. Pode usar as instruções ROLLUP, CUBE, GROUPING SETS ou as cláusulas UNION of GROUP BY para os objetivos em que lhe parecer adequado.

# %% [markdown]
# 1. Determinar que paciente(s) tiveram menos progresso no tratamento das suas doenças do foro ortopédico para atribuição de uma consulta gratuita. Considera-se que o indicador de falta de progresso é o intervalo temporal máximo entre duas observações do mesmo sintoma (i.e. registos de tipo ‘observacao’ com a mesma chave e com valor NULL) em consultas de ortopedia.

# %%
# %%sql
# REFRESH MATERIALIZED VIEW historial_paciente;
# SELECT DISTINCT ssn
# FROM historial_paciente
# WHERE especialidade = 'ortopedia' AND tipo = 'observacao' AND valor IS NULL
# GROUP BY ssn, chave
# HAVING MAX(data) - MIN(data) >= ALL (
#     SELECT MAX(data) - MIN(data)
#     FROM historial_paciente
#     WHERE especialidade = 'ortopedia' AND tipo = 'observacao' AND valor IS NULL
#     GROUP BY ssn, chave
# );
# Out:
# 2 rows affected.
# +-------------+
# |     ssn     |
# +-------------+
# | 32790357928 |
# | 35526350773 |
# +-------------+

# %% [markdown]
# 2. Determinar que medicamentos estão a ser usados para tratar doenças crónicas do foro cardiológico. Considera-se que qualificam quaisquer medicamentos receitados ao mesmo paciente (qualquer que ele seja) pelo menos uma vez por mês durante os últimos doze meses, em consultas de cardiologia.

# %%
# %%sql
# REFRESH MATERIALIZED VIEW historial_paciente;
# SELECT DISTINCT chave AS medicamento
# FROM historial_paciente
# WHERE especialidade = 'cardiologia' AND tipo = 'receita' AND
#     data BETWEEN (CURRENT_DATE - interval '1 year') AND CURRENT_DATE
# GROUP BY ssn, chave
# HAVING COUNT(data) >= 12;
# Out:
# 1 rows affected.
# +-------------+
# | medicamento |
# +-------------+
# |    vinho    |
# +-------------+

# %% [markdown]
# 3. Explorar as quantidades totais receitadas de cada medicamento em 2023, globalmente, e com drill down nas dimensões espaço (localidade > clinica), tempo (mes > dia_do_mes), e médico  (especialidade > nome \[do médico]), separadamente.

# %%
# %%sql
# REFRESH MATERIALIZED VIEW historial_paciente;
# SELECT
#     SUBSTRING(localidade FROM '[0-9]{4}-[0-9]{3} (.+)$') AS localidade_clinica, h.nome,
#     mes, dia_do_mes,
#     h.especialidade, m.nome AS nome_medico,
#     chave AS medicamento, SUM(valor) AS quantidade_total
# FROM
#     historial_paciente h INNER JOIN medico m USING(nif)
# WHERE
#     tipo = 'receita' AND ano = 2023
# GROUP BY medicamento, GROUPING SETS (ROLLUP(localidade_clinica, h.nome),
#                               (mes), (mes, dia_do_mes),
#                               (h.especialidade), (h.especialidade, nome_medico));
# Out:
# 32904 rows affected.
# +--------------------+-----------+------+------------+---------------+-------------+-------------+------------------+
# | localidade_clinica |    nome   | mes  | dia_do_mes | especialidade | nome_medico | medicamento | quantidade_total |
# +--------------------+-----------+------+------------+---------------+-------------+-------------+------------------+
# |      Bobadela      | Clínica C | None |    None    |      None     |     None    |   Adderall  |      954.0       |
# |      Bobadela      | Clínica D | None |    None    |      None     |     None    |   Adderall  |      897.0       |
# |      Bobadela      |    None   | None |    None    |      None     |     None    |   Adderall  |      1851.0      |
# |     Moscavide      | Clínica A | None |    None    |      None     |     None    |   Adderall  |      948.0       |
# |     Moscavide      | Clínica B | None |    None    |      None     |     None    |   Adderall  |      953.0       |
# |     Moscavide      |    None   | None |    None    |      None     |     None    |   Adderall  |      1901.0      |
# |      Odivelas      | Clínica E | None |    None    |      None     |     None    |   Adderall  |      935.0       |
# |      Odivelas      |    None   | None |    None    |      None     |     None    |   Adderall  |      935.0       |
# |        None        |    None   | None |    None    |      None     |     None    |   Adderall  |      4687.0      |
# |      Bobadela      | Clínica C | None |    None    |      None     |     None    |    Advil    |      503.0       |
# |      Bobadela      | Clínica D | None |    None    |      None     |     None    |    Advil    |      508.0       |
# |      Bobadela      |    None   | None |    None    |      None     |     None    |    Advil    |      1011.0      |
# |     Moscavide      | Clínica A | None |    None    |      None     |     None    |    Advil    |      519.0       |
# |     Moscavide      | Clínica B | None |    None    |      None     |     None    |    Advil    |      528.0       |
# |     Moscavide      |    None   | None |    None    |      None     |     None    |    Advil    |      1047.0      |
# |      Odivelas      | Clínica E | None |    None    |      None     |     None    |    Advil    |      433.0       |
# |      Odivelas      |    None   | None |    None    |      None     |     None    |    Advil    |      433.0       |
# |        None        |    None   | None |    None    |      None     |     None    |    Advil    |      2491.0      |
# |      Bobadela      | Clínica C | None |    None    |      None     |     None    |  Albuterol  |      435.0       |
# |      Bobadela      | Clínica D | None |    None    |      None     |     None    |  Albuterol  |      462.0       |
# |      Bobadela      |    None   | None |    None    |      None     |     None    |  Albuterol  |      897.0       |
# |     Moscavide      | Clínica A | None |    None    |      None     |     None    |  Albuterol  |      574.0       |
# |     Moscavide      | Clínica B | None |    None    |      None     |     None    |  Albuterol  |      487.0       |
# |     Moscavide      |    None   | None |    None    |      None     |     None    |  Albuterol  |      1061.0      |
# |      Odivelas      | Clínica E | None |    None    |      None     |     None    |  Albuterol  |      483.0       |
# |      Odivelas      |    None   | None |    None    |      None     |     None    |  Albuterol  |      483.0       |
# |        None        |    None   | None |    None    |      None     |     None    |  Albuterol  |      2441.0      |
# |      Bobadela      | Clínica C | None |    None    |      None     |     None    |   Allegra   |      461.0       |
# |      Bobadela      | Clínica D | None |    None    |      None     |     None    |   Allegra   |      499.0       |
# |      Bobadela      |    None   | None |    None    |      None     |     None    |   Allegra   |      960.0       |
# |     Moscavide      | Clínica A | None |    None    |      None     |     None    |   Allegra   |      482.0       |
# |     Moscavide      | Clínica B | None |    None    |      None     |     None    |   Allegra   |      503.0       |
# |     Moscavide      |    None   | None |    None    |      None     |     None    |   Allegra   |      985.0       |
# |      Odivelas      | Clínica E | None |    None    |      None     |     None    |   Allegra   |      495.0       |
# |      Odivelas      |    None   | None |    None    |      None     |     None    |   Allegra   |      495.0       |
# |        None        |    None   | None |    None    |      None     |     None    |   Allegra   |      2440.0      |
# |      Bobadela      | Clínica C | None |    None    |      None     |     None    |    Ambien   |      1455.0      |
# |      Bobadela      | Clínica D | None |    None    |      None     |     None    |    Ambien   |      1405.0      |
# |      Bobadela      |    None   | None |    None    |      None     |     None    |    Ambien   |      2860.0      |
# |     Moscavide      | Clínica A | None |    None    |      None     |     None    |    Ambien   |      1401.0      |
# |     Moscavide      | Clínica B | None |    None    |      None     |     None    |    Ambien   |      1343.0      |
# |     Moscavide      |    None   | None |    None    |      None     |     None    |    Ambien   |      2744.0      |
# |      Odivelas      | Clínica E | None |    None    |      None     |     None    |    Ambien   |      1495.0      |
# |      Odivelas      |    None   | None |    None    |      None     |     None    |    Ambien   |      1495.0      |
# |        None        |    None   | None |    None    |      None     |     None    |    Ambien   |      7099.0      |
# |      Bobadela      | Clínica C | None |    None    |      None     |     None    | Amoxicillin |      505.0       |
# |      Bobadela      | Clínica D | None |    None    |      None     |     None    | Amoxicillin |      527.0       |
# |      Bobadela      |    None   | None |    None    |      None     |     None    | Amoxicillin |      1032.0      |
# |     Moscavide      | Clínica A | None |    None    |      None     |     None    | Amoxicillin |      537.0       |
# |     Moscavide      | Clínica B | None |    None    |      None     |     None    | Amoxicillin |      462.0       |
# |     Moscavide      |    None   | None |    None    |      None     |     None    | Amoxicillin |      999.0       |
# |      Odivelas      | Clínica E | None |    None    |      None     |     None    | Amoxicillin |      513.0       |
# |      Odivelas      |    None   | None |    None    |      None     |     None    | Amoxicillin |      513.0       |
# |        None        |    None   | None |    None    |      None     |     None    | Amoxicillin |      2544.0      |
# |      Bobadela      | Clínica C | None |    None    |      None     |     None    |   Aricept   |      424.0       |
# |      Bobadela      | Clínica D | None |    None    |      None     |     None    |   Aricept   |      533.0       |
# |      Bobadela      |    None   | None |    None    |      None     |     None    |   Aricept   |      957.0       |
# |     Moscavide      | Clínica A | None |    None    |      None     |     None    |   Aricept   |      510.0       |
# |     Moscavide      | Clínica B | None |    None    |      None     |     None    |   Aricept   |      515.0       |
# |     Moscavide      |    None   | None |    None    |      None     |     None    |   Aricept   |      1025.0      |
# |      Odivelas      | Clínica E | None |    None    |      None     |     None    |   Aricept   |      532.0       |
# |      Odivelas      |    None   | None |    None    |      None     |     None    |   Aricept   |      532.0       |
# |        None        |    None   | None |    None    |      None     |     None    |   Aricept   |      2514.0      |
# |      Bobadela      | Clínica C | None |    None    |      None     |     None    |    Ativan   |      905.0       |
# |      Bobadela      | Clínica D | None |    None    |      None     |     None    |    Ativan   |      926.0       |
# |      Bobadela      |    None   | None |    None    |      None     |     None    |    Ativan   |      1831.0      |
# |     Moscavide      | Clínica A | None |    None    |      None     |     None    |    Ativan   |      1014.0      |
# |     Moscavide      | Clínica B | None |    None    |      None     |     None    |    Ativan   |      928.0       |
# |     Moscavide      |    None   | None |    None    |      None     |     None    |    Ativan   |      1942.0      |
# |      Odivelas      | Clínica E | None |    None    |      None     |     None    |    Ativan   |      996.0       |
# |      Odivelas      |    None   | None |    None    |      None     |     None    |    Ativan   |      996.0       |
# |        None        |    None   | None |    None    |      None     |     None    |    Ativan   |      4769.0      |
# |      Bobadela      | Clínica C | None |    None    |      None     |     None    |    Boniva   |      430.0       |
# |      Bobadela      | Clínica D | None |    None    |      None     |     None    |    Boniva   |      520.0       |
# |      Bobadela      |    None   | None |    None    |      None     |     None    |    Boniva   |      950.0       |
# |     Moscavide      | Clínica A | None |    None    |      None     |     None    |    Boniva   |      473.0       |
# |     Moscavide      | Clínica B | None |    None    |      None     |     None    |    Boniva   |      510.0       |
# |     Moscavide      |    None   | None |    None    |      None     |     None    |    Boniva   |      983.0       |
# |      Odivelas      | Clínica E | None |    None    |      None     |     None    |    Boniva   |      508.0       |
# |      Odivelas      |    None   | None |    None    |      None     |     None    |    Boniva   |      508.0       |
# |        None        |    None   | None |    None    |      None     |     None    |    Boniva   |      2441.0      |
# |      Bobadela      | Clínica C | None |    None    |      None     |     None    |   Celebrex  |      512.0       |
# |      Bobadela      | Clínica D | None |    None    |      None     |     None    |   Celebrex  |      511.0       |
# |      Bobadela      |    None   | None |    None    |      None     |     None    |   Celebrex  |      1023.0      |
# |     Moscavide      | Clínica A | None |    None    |      None     |     None    |   Celebrex  |      476.0       |
# |     Moscavide      | Clínica B | None |    None    |      None     |     None    |   Celebrex  |      543.0       |
# |     Moscavide      |    None   | None |    None    |      None     |     None    |   Celebrex  |      1019.0      |
# |      Odivelas      | Clínica E | None |    None    |      None     |     None    |   Celebrex  |      506.0       |
# |      Odivelas      |    None   | None |    None    |      None     |     None    |   Celebrex  |      506.0       |
# |        None        |    None   | None |    None    |      None     |     None    |   Celebrex  |      2548.0      |
# |      Bobadela      | Clínica C | None |    None    |      None     |     None    |    Celexa   |      498.0       |
# |      Bobadela      | Clínica D | None |    None    |      None     |     None    |    Celexa   |      456.0       |
# |      Bobadela      |    None   | None |    None    |      None     |     None    |    Celexa   |      954.0       |
# |     Moscavide      | Clínica A | None |    None    |      None     |     None    |    Celexa   |      499.0       |
# |     Moscavide      | Clínica B | None |    None    |      None     |     None    |    Celexa   |      464.0       |
# |     Moscavide      |    None   | None |    None    |      None     |     None    |    Celexa   |      963.0       |
# |      Odivelas      | Clínica E | None |    None    |      None     |     None    |    Celexa   |      448.0       |
# |      Odivelas      |    None   | None |    None    |      None     |     None    |    Celexa   |      448.0       |
# |        None        |    None   | None |    None    |      None     |     None    |    Celexa   |      2365.0      |
# |      Bobadela      | Clínica C | None |    None    |      None     |     None    |    Cialis   |      478.0       |
# +--------------------+-----------+------+------------+---------------+-------------+-------------+------------------+
# Truncated to displaylimit of 100.

# %% [markdown]
# 4. Determinar se há enviesamento na medição de algum parâmetros entre clínicas, especialidades médicas ou médicos, sendo para isso necessário listar o valor médio e desvio padrão de todos os parâmetros de observações métricas (i.e. com valor não NULL) com drill down na dimensão médico (globalmente > especialidade > nome \[do médico]) e drill down adicional (sobre o anterior) por clínica.

# %%
# %%sql
# REFRESH MATERIALIZED VIEW historial_paciente;
# SELECT
#     chave AS parametro, h.especialidade, m.nome AS nome_medico, h.nome,
#     AVG(valor) AS media, STDDEV(valor) AS desvio_padrao
# FROM
#     historial_paciente h INNER JOIN medico m USING(nif)
# WHERE
#     tipo = 'observacao' AND valor IS NOT NULL
# GROUP BY parametro, ROLLUP(h.especialidade, m.nome, h.nome);
# Out:
# 6973 rows affected.
# +------------------+---------------+------------------------+-----------+--------------------+--------------------+
# |    parametro     | especialidade |      nome_medico       |    nome   |       media        |   desvio_padrao    |
# +------------------+---------------+------------------------+-----------+--------------------+--------------------+
# | colesterol total |  cardiologia  |       Igor Silva       | Clínica A | 50.447050897712685 | 34.26350155609049  |
# | colesterol total |  cardiologia  |       Igor Silva       | Clínica B |  52.9686254204476  | 22.537650353071456 |
# | colesterol total |  cardiologia  |       Igor Silva       | Clínica C | 47.143351354027615 | 31.88897515039336  |
# | colesterol total |  cardiologia  |       Igor Silva       | Clínica D | 45.21389392203725  | 28.100310763306837 |
# | colesterol total |  cardiologia  |       Igor Silva       | Clínica E | 55.07979471059791  | 29.12889522133795  |
# | colesterol total |  cardiologia  |       Igor Silva       |    None   | 49.34203212139264  | 29.183628363734336 |
# | colesterol total |  cardiologia  |    Lisandro Correia    | Clínica A | 52.89968784011404  | 30.507032339153326 |
# | colesterol total |  cardiologia  |    Lisandro Correia    | Clínica B | 45.46558793553691  | 30.042469918489637 |
# | colesterol total |  cardiologia  |    Lisandro Correia    | Clínica C | 61.13261447441172  | 27.090617932317986 |
# | colesterol total |  cardiologia  |    Lisandro Correia    | Clínica D | 43.85788156856959  |  33.1781194214382  |
# | colesterol total |  cardiologia  |    Lisandro Correia    | Clínica E | 48.60467661353808  | 28.322927438424767 |
# | colesterol total |  cardiologia  |    Lisandro Correia    |    None   | 52.04892975781997  | 29.299169775851123 |
# | colesterol total |  cardiologia  | Mafalda Esteves-Coelho | Clínica A | 33.16775642853462  | 26.97336162577344  |
# | colesterol total |  cardiologia  | Mafalda Esteves-Coelho | Clínica B |  49.1945012466207  | 31.290357346945836 |
# | colesterol total |  cardiologia  | Mafalda Esteves-Coelho | Clínica C | 54.827916946877835 | 26.29195846892267  |
# | colesterol total |  cardiologia  | Mafalda Esteves-Coelho | Clínica D |  42.5984522601143  | 29.396609551114697 |
# | colesterol total |  cardiologia  | Mafalda Esteves-Coelho | Clínica E | 43.72817367378046  | 29.330428840459092 |
# | colesterol total |  cardiologia  | Mafalda Esteves-Coelho |    None   | 46.56577810748618  | 29.223947416703517 |
# | colesterol total |  cardiologia  |     Mauro Assunção     | Clínica A | 32.62776978969614  | 30.627058979518292 |
# | colesterol total |  cardiologia  |     Mauro Assunção     | Clínica B | 34.31689581098697  | 19.977788099061367 |
# | colesterol total |  cardiologia  |     Mauro Assunção     | Clínica C | 60.68056619072598  | 31.005263000816296 |
# | colesterol total |  cardiologia  |     Mauro Assunção     | Clínica D | 51.83425221868766  | 31.41965074534504  |
# | colesterol total |  cardiologia  |     Mauro Assunção     | Clínica E | 51.37242951207645  | 27.49631805198404  |
# | colesterol total |  cardiologia  |     Mauro Assunção     |    None   | 47.22817383829617  | 29.746555927721765 |
# | colesterol total |  cardiologia  |          None          |    None   | 48.91392701480311  | 29.301587689511894 |
# | colesterol total | clínica geral |     Alice Ribeiro      | Clínica A | 59.94923463430516  | 28.03886609576602  |
# | colesterol total | clínica geral |     Alice Ribeiro      | Clínica B | 45.71794186463446  | 34.32260262981267  |
# | colesterol total | clínica geral |     Alice Ribeiro      | Clínica C | 42.62629888351454  | 29.960640421497565 |
# | colesterol total | clínica geral |     Alice Ribeiro      | Clínica D | 64.43284300948193  |  34.2772014780478  |
# | colesterol total | clínica geral |     Alice Ribeiro      | Clínica E | 51.36935374997015  | 24.638664597923224 |
# | colesterol total | clínica geral |     Alice Ribeiro      |    None   | 51.77234354062332  | 30.22503434053918  |
# | colesterol total | clínica geral |    Benjamim Machado    | Clínica A | 51.01532712626594  | 24.75680941176536  |
# | colesterol total | clínica geral |    Benjamim Machado    | Clínica B | 55.003030658917545 | 30.529567289088327 |
# | colesterol total | clínica geral |    Benjamim Machado    | Clínica C | 53.59228323078001  | 29.37241695810636  |
# | colesterol total | clínica geral |    Benjamim Machado    | Clínica D | 30.060062256301038 | 21.683429497844532 |
# | colesterol total | clínica geral |    Benjamim Machado    | Clínica E | 55.98065156267098  | 31.833427689644044 |
# | colesterol total | clínica geral |    Benjamim Machado    |    None   | 51.533034222723174 | 28.97688857809891  |
# | colesterol total | clínica geral |   Carlota-Íris Leal    | Clínica A | 42.94463271170234  | 36.933051608295436 |
# | colesterol total | clínica geral |   Carlota-Íris Leal    | Clínica B | 48.45855143668134  | 26.545952140881425 |
# | colesterol total | clínica geral |   Carlota-Íris Leal    | Clínica C | 47.161782698284675 | 28.10052023983709  |
# | colesterol total | clínica geral |   Carlota-Íris Leal    | Clínica D | 37.55432053515109  | 31.512021198135862 |
# | colesterol total | clínica geral |   Carlota-Íris Leal    | Clínica E | 54.52021841036094  | 33.73493929210479  |
# | colesterol total | clínica geral |   Carlota-Íris Leal    |    None   | 46.81247029859258  | 31.30193863501899  |
# | colesterol total | clínica geral |    Constança Garcia    | Clínica A | 42.44887590659263  | 28.193136802536216 |
# | colesterol total | clínica geral |    Constança Garcia    | Clínica B | 38.04538878782516  | 29.89663263911499  |
# | colesterol total | clínica geral |    Constança Garcia    | Clínica C | 59.236873077138114 | 29.02098988014801  |
# | colesterol total | clínica geral |    Constança Garcia    | Clínica D | 40.32548421939802  | 20.98368103607566  |
# | colesterol total | clínica geral |    Constança Garcia    | Clínica E | 57.76897596946223  | 27.28055223621874  |
# | colesterol total | clínica geral |    Constança Garcia    |    None   | 49.73931862284874  | 28.438351858944465 |
# | colesterol total | clínica geral |      Hugo Valente      | Clínica A | 56.33443436351246  | 32.838980531917215 |
# | colesterol total | clínica geral |      Hugo Valente      | Clínica B | 62.37111906643209  | 31.295890825678192 |
# | colesterol total | clínica geral |      Hugo Valente      | Clínica C | 48.249323702004105 | 25.39596892525532  |
# | colesterol total | clínica geral |      Hugo Valente      | Clínica D | 42.074965842695846 | 30.11047735385501  |
# | colesterol total | clínica geral |      Hugo Valente      | Clínica E | 53.09188799026352  | 32.555414924269506 |
# | colesterol total | clínica geral |      Hugo Valente      |    None   | 52.33170472788401  | 30.995801190727022 |
# | colesterol total | clínica geral |       Inês Alves       | Clínica A | 50.40966148768966  | 31.299980189048668 |
# | colesterol total | clínica geral |       Inês Alves       | Clínica B | 42.455449055266754 | 29.79835249726956  |
# | colesterol total | clínica geral |       Inês Alves       | Clínica C | 48.098168670331866 | 34.13994917924704  |
# | colesterol total | clínica geral |       Inês Alves       | Clínica D | 47.84387553946956  |  29.5657882014986  |
# | colesterol total | clínica geral |       Inês Alves       | Clínica E | 44.73366405591441  | 22.01294154105015  |
# | colesterol total | clínica geral |       Inês Alves       |    None   | 47.31697638881616  | 28.88156455266669  |
# | colesterol total | clínica geral | Isabela Barros-Correia | Clínica A | 55.876942932281196 | 31.362621654242677 |
# | colesterol total | clínica geral | Isabela Barros-Correia | Clínica B | 50.75303627736044  | 34.087996771835016 |
# | colesterol total | clínica geral | Isabela Barros-Correia | Clínica C | 47.52091528115834  | 28.17411666701548  |
# | colesterol total | clínica geral | Isabela Barros-Correia | Clínica D | 24.195017379622566 | 14.937561939973271 |
# | colesterol total | clínica geral | Isabela Barros-Correia | Clínica E | 51.14231186417313  | 31.476862210499455 |
# | colesterol total | clínica geral | Isabela Barros-Correia |    None   | 49.37132921942054  | 30.54246005704772  |
# | colesterol total | clínica geral |      Ivan Garcia       | Clínica A |  38.7610465946053  | 26.08431423575216  |
# | colesterol total | clínica geral |      Ivan Garcia       | Clínica B | 39.56640030783154  | 30.92702495893321  |
# | colesterol total | clínica geral |      Ivan Garcia       | Clínica C | 55.53490149026659  | 29.14281333769124  |
# | colesterol total | clínica geral |      Ivan Garcia       | Clínica D | 46.11811509900459  | 28.212325791442943 |
# | colesterol total | clínica geral |      Ivan Garcia       | Clínica E | 51.22982421579522  | 26.948489123858774 |
# | colesterol total | clínica geral |      Ivan Garcia       |    None   | 45.55586035582901  | 27.59007065429091  |
# | colesterol total | clínica geral |      Jaime Neves       | Clínica A | 52.55476806012573  | 28.707567594772556 |
# | colesterol total | clínica geral |      Jaime Neves       | Clínica B | 56.17082387674342  | 27.523687309476436 |
# | colesterol total | clínica geral |      Jaime Neves       | Clínica C | 60.89041620432692  | 24.42080529843099  |
# | colesterol total | clínica geral |      Jaime Neves       | Clínica D | 61.22120875334262  | 27.28218110607247  |
# | colesterol total | clínica geral |      Jaime Neves       | Clínica E | 53.88586478262342  | 21.154231488268234 |
# | colesterol total | clínica geral |      Jaime Neves       |    None   | 56.273688406507794 | 26.218424321994515 |
# | colesterol total | clínica geral |       Joana Leal       | Clínica A | 51.43934883611314  | 28.792323385004003 |
# | colesterol total | clínica geral |       Joana Leal       | Clínica B | 44.11703646281655  | 28.637718763072094 |
# | colesterol total | clínica geral |       Joana Leal       | Clínica C | 53.76614097790405  | 23.932738412635445 |
# | colesterol total | clínica geral |       Joana Leal       | Clínica D | 53.331239273031294 | 22.437467451605755 |
# | colesterol total | clínica geral |       Joana Leal       | Clínica E | 47.39996957052544  | 20.545973354057445 |
# | colesterol total | clínica geral |       Joana Leal       |    None   | 50.00822241353591  | 25.569945621379546 |
# | colesterol total | clínica geral |    Lucas Henriques     | Clínica A | 56.430803364617724 | 28.741196481014335 |
# | colesterol total | clínica geral |    Lucas Henriques     | Clínica B | 48.912384150138294 | 25.230965941778983 |
# | colesterol total | clínica geral |    Lucas Henriques     | Clínica C | 48.80689653228916  | 26.687937426205647 |
# | colesterol total | clínica geral |    Lucas Henriques     | Clínica D | 46.53299959652702  | 17.25995589159422  |
# | colesterol total | clínica geral |    Lucas Henriques     | Clínica E | 50.767329991497576 | 32.49282058353557  |
# | colesterol total | clínica geral |    Lucas Henriques     |    None   | 51.20589705915501  | 26.261298547755384 |
# | colesterol total | clínica geral |   Margarida Freitas    | Clínica A | 61.19525914157296  | 28.854091109902043 |
# | colesterol total | clínica geral |   Margarida Freitas    | Clínica B | 35.56111089242702  | 26.974594742646527 |
# | colesterol total | clínica geral |   Margarida Freitas    | Clínica C | 46.40516972169279  | 30.411569107493705 |
# | colesterol total | clínica geral |   Margarida Freitas    | Clínica D | 36.49420050636477  | 25.229695166989057 |
# | colesterol total | clínica geral |   Margarida Freitas    | Clínica E | 50.86582950562237  | 25.99581943429941  |
# | colesterol total | clínica geral |   Margarida Freitas    |    None   | 49.82337794404454  | 28.635154233727764 |
# | colesterol total | clínica geral |      Maria Paiva       | Clínica A | 42.554046994019735 | 27.311726864233247 |
# | colesterol total | clínica geral |      Maria Paiva       | Clínica B | 44.89258627547344  | 27.255298916835635 |
# | colesterol total | clínica geral |      Maria Paiva       | Clínica C | 45.884521091968885 | 27.222466710327513 |
# +------------------+---------------+------------------------+-----------+--------------------+--------------------+
# Truncated to displaylimit of 100.

# %% [markdown]
# ## 6. Índices

# %% [markdown]
# Apresente as instruções SQL para criação de índices para melhorar os tempos de cada uma das consultas listadas abaixo sobre a base de dados ‘Saude’. Justifique a sua escolha de tabela(s), atributo(s) e tipo(s) de índice, explicando que operações seriam otimizadas e como. Considere que não existam índices nas tabelas, além daqueles implícitos ao declarar chaves primárias e estrangeiras, e para efeitos deste exercício, suponha que o tamanho das tabelas excede a memória disponível em várias ordens de magnitude.

# %% [markdown]
# ### 6.1
# SELECT nome
# FROM paciente
# JOIN consulta USING (ssn)
# JOIN observacao USING (id)
# WHERE parametro = ‘pressão diastólica’
# AND valor >= 9;

# %%
# %%sql
# -- Ao utilizar um índice conjunto b-tree em (parametro, valor) na tabela observacao, o query apresentado
# -- é mais eficiente a aplicar o filtro "WHERE parametro = 'pressão diastólica' AND valor >= 9" pois passa
# -- de um Sequential Scan na tabela observacao para um Index Scan.
# DROP INDEX IF EXISTS observacao_val_par;
# CREATE INDEX observacao_val_par ON observacao (parametro, valor);

# %% [markdown]
# ### Justificação
#
# ...

# %% [markdown]
# ### 6.2
# SELECT especialidade, SUM(quantidade) AS qtd
# FROM medico
# JOIN consulta USING (nif)
# JOIN receita USING (codigo_ssn)
# WHERE data BETWEEN ‘2023-01-01’ AND ‘2023-12-31’
# GROUP BY especialidade
# ORDER BY qtd;

# %%
# %%sql
# DROP INDEX IF EXISTS consulta_data;
# CREATE INDEX consulta_data ON consulta (data);
#
# DROP INDEX IF EXISTS medico_esp;
# CREATE INDEX medico_esp ON medico (especialidade);

# %% [markdown]
# ### Justificação
#
# ...
